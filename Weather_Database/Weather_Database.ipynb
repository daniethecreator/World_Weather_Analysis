# %%
# Import the random module.
import random
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
#Import numpy
import numpy as np
#Import pandas
import pandas as pd
# Import the API key.
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
#Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 16 | chokurdakh
# Processing Record 2 of Set 16 | carnarvon
# Processing Record 3 of Set 16 | prince george
# Processing Record 4 of Set 16 | georgetown
# Processing Record 5 of Set 16 | hilo
# Processing Record 6 of Set 16 | antofagasta
# Processing Record 7 of Set 16 | straumen
# Processing Record 8 of Set 16 | faanui
# Processing Record 9 of Set 16 | hermanus
# Processing Record 10 of Set 16 | port elizabeth
# Processing Record 11 of Set 16 | butaritari
# Processing Record 12 of Set 16 | mandan
# Processing Record 13 of Set 16 | arraial do cabo
# Processing Record 14 of Set 16 | provideniya
# Processing Record 15 of Set 16 | aloleng
# Processing Record 16 of Set 16 | college
# Processing Record 17 of Set 16 | avarua
# Processing Record 18 of Set 16 | tilichiki
# Processing Record 19 of Set 16 | port lincoln
# Processing Record 20 of Set 16 | busselton
# Processing Record 21 of Set 16 | tabou
# Processing Record 22 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 16 | sao felix do xingu
# Processing Record 24 of Set 16 | kangaatsiaq
# Processing Record 25 of Set 16 | jamestown
# Processing Record 26 of Set 16 | ust-kan
# Processing Record 27 of Set 16 | yar-sale
# Processing Record 28 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 16 | talcahuano
# Processing Record 30 of Set 16 | orlik
# Processing Record 31 of Set 16 | sao filipe
# Processing Record 32 of Set 16 | new norfolk
# Processing Record 33 of Set 16 | broome
# Processing Record 34 of Set 16 | palauig
# Processing Record 35 of Set 16 | gorontalo
# Processing Record 36 of Set 16 | barrow
# Processing Record 37 of Set 16 | dunedin
# Processing Record 38 of Set 16 | belaya gora
# Processing Record 39 of Set 16 | takoradi
# Processing Record 40 of Set 16 | rapid valley
# Processing Record 41 of Set 16 | sorland
# Processing Record 42 of Set 16 | auki
# Processing Record 43 of Set 16 | buraydah
# Processing Record 44 of Set 16 | qaanaaq
# Processing Record 45 of Set 16 | kirakira
# Processing Record 46 of Set 16 | hobart
# Processing Record 47 of Set 16 | richards bay
# Processing Record 48 of Set 16 | wajir
# Processing Record 49 of Set 16 | marawi
# Processing Record 50 of Set 16 | znamenskoye
# Processing Record 1 of Set 17 | inhambane
# Processing Record 2 of Set 17 | linxia
# Processing Record 3 of Set 17 | keti bandar
# Processing Record 4 of Set 17 | leningradskiy
# Processing Record 5 of Set 17 | tiksi
# Processing Record 6 of Set 17 | saskylakh
# Processing Record 7 of Set 17 | okhotsk
# Processing Record 8 of Set 17 | cape town
# Processing Record 9 of Set 17 | muros
# Processing Record 10 of Set 17 | bluff
# Processing Record 11 of Set 17 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 17 | los llanos de aridane
# Processing Record 13 of Set 17 | alyangula
# Processing Record 14 of Set 17 | nantucket
# Processing Record 15 of Set 17 | yellowknife
# Processing Record 16 of Set 17 | kieta
# Processing Record 17 of Set 17 | venado tuerto
# Processing Record 18 of Set 17 | grindavik
# Processing Record 19 of Set 17 | awjilah
# Processing Record 20 of Set 17 | punta arenas
# Processing Record 21 of Set 17 | vaini
# Processing Record 22 of Set 17 | guerrero negro
# Processing Record 23 of Set 17 | namibe
# Processing Record 24 of Set 17 | torbay
# Processing Record 25 of Set 17 | karauzyak
# City not found. Skipping...
# Processing Record 26 of Set 17 | kununurra
# Processing Record 27 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 17 | fayetteville
# Processing Record 30 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 17 | kampot
# Processing Record 32 of Set 17 | bethel
# Processing Record 33 of Set 17 | sur
# Processing Record 34 of Set 17 | port alfred
# Processing Record 35 of Set 17 | seybaplaya
# Processing Record 36 of Set 17 | srednekolymsk
# Processing Record 37 of Set 17 | geraldton
# Processing Record 38 of Set 17 | egvekinot
# Processing Record 39 of Set 17 | olafsvik
# Processing Record 40 of Set 17 | portland
# Processing Record 41 of Set 17 | atuona
# Processing Record 42 of Set 17 | mar del plata
# Processing Record 43 of Set 17 | yinchuan
# Processing Record 44 of Set 17 | port blair
# Processing Record 45 of Set 17 | praia da vitoria
# Processing Record 46 of Set 17 | rikitea
# Processing Record 47 of Set 17 | toda raisingh
# Processing Record 48 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 17 | saint-philippe
# Processing Record 50 of Set 17 | batemans bay
# Processing Record 1 of Set 18 | vardo
# Processing Record 2 of Set 18 | luderitz
# Processing Record 3 of Set 18 | puerto ayora
# Processing Record 4 of Set 18 | kodiak
# Processing Record 5 of Set 18 | shingu
# Processing Record 6 of Set 18 | maningrida
# Processing Record 7 of Set 18 | moa
# Processing Record 8 of Set 18 | talnakh
# Processing Record 9 of Set 18 | kapaa
# Processing Record 10 of Set 18 | shimoda
# Processing Record 11 of Set 18 | marzuq
# Processing Record 12 of Set 18 | ancud
# Processing Record 13 of Set 18 | kutum
# Processing Record 14 of Set 18 | sakakah
# Processing Record 15 of Set 18 | ouadda
# Processing Record 16 of Set 18 | ponta do sol
# Processing Record 17 of Set 18 | alofi
# Processing Record 18 of Set 18 | ushuaia
# Processing Record 19 of Set 18 | ishurdi
# Processing Record 20 of Set 18 | northam
# Processing Record 21 of Set 18 | mangrol
# Processing Record 22 of Set 18 | mosquera
# Processing Record 23 of Set 18 | lata
# Processing Record 24 of Set 18 | nuqui
# Processing Record 25 of Set 18 | deputatskiy
# Processing Record 26 of Set 18 | ayame
# Processing Record 27 of Set 18 | aripuana
# Processing Record 28 of Set 18 | bredasdorp
# Processing Record 29 of Set 18 | umtata
# Processing Record 30 of Set 18 | shurob
# Processing Record 31 of Set 18 | asau
# Processing Record 32 of Set 18 | east london
# Processing Record 33 of Set 18 | ribeira grande
# Processing Record 34 of Set 18 | albany
# Processing Record 35 of Set 18 | aklavik
# Processing Record 36 of Set 18 | griffith
# Processing Record 37 of Set 18 | kaitangata
# Processing Record 38 of Set 18 | hami
# Processing Record 39 of Set 18 | sakata
# Processing Record 40 of Set 18 | bontang
# Processing Record 41 of Set 18 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 18 | xining
# Processing Record 43 of Set 18 | mataura
# Processing Record 44 of Set 18 | gashua
# Processing Record 45 of Set 18 | mount isa
# Processing Record 46 of Set 18 | lagoa
# Processing Record 47 of Set 18 | synya
# Processing Record 48 of Set 18 | karratha
# Processing Record 49 of Set 18 | kouango
# Processing Record 50 of Set 18 | mayor pablo lagerenza
# Processing Record 1 of Set 19 | san jorge
# Processing Record 2 of Set 19 | te anau
# Processing Record 3 of Set 19 | chuy
# Processing Record 4 of Set 19 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 19 | cayenne
# Processing Record 6 of Set 19 | bulgan
# Processing Record 7 of Set 19 | tuktoyaktuk
# Processing Record 8 of Set 19 | luena
# Processing Record 9 of Set 19 | castro
# Processing Record 10 of Set 19 | kudahuvadhoo
# Processing Record 11 of Set 19 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 19 | lianzhou
# Processing Record 13 of Set 19 | pahrump
# Processing Record 14 of Set 19 | debre sina
# Processing Record 15 of Set 19 | vila velha
# Processing Record 16 of Set 19 | amalapuram
# Processing Record 17 of Set 19 | syracuse
# Processing Record 18 of Set 19 | salta
# Processing Record 19 of Set 19 | nyurba
# Processing Record 20 of Set 19 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 19 | cherskiy
# Processing Record 22 of Set 19 | dikson
# Processing Record 23 of Set 19 | ust-koksa
# Processing Record 24 of Set 19 | rolim de moura
# City not found. Skipping...
# Processing Record 25 of Set 19 | mwinilunga
# Processing Record 26 of Set 19 | quang ngai
# Processing Record 27 of Set 19 | port hedland
# Processing Record 28 of Set 19 | kruisfontein
# Processing Record 29 of Set 19 | rawson
# Processing Record 30 of Set 19 | methoni
# Processing Record 31 of Set 19 | troitskoye
# Processing Record 32 of Set 19 | dubki
# Processing Record 33 of Set 19 | becerril
# Processing Record 34 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 19 | gizo
# Processing Record 36 of Set 19 | aksu
# Processing Record 37 of Set 19 | la palma
# Processing Record 38 of Set 19 | caravelas
# Processing Record 39 of Set 19 | ginda
# Processing Record 40 of Set 19 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 19 | ternate
# Processing Record 42 of Set 19 | cap malheureux
# Processing Record 43 of Set 19 | batagay
# Processing Record 44 of Set 19 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 19 | lahaina
# Processing Record 46 of Set 19 | escalerillas
# Processing Record 47 of Set 19 | udachnyy
# Processing Record 48 of Set 19 | zabid
# Processing Record 49 of Set 19 | airai
# Processing Record 50 of Set 19 | roebourne
# Processing Record 1 of Set 20 | kavieng
# Processing Record 2 of Set 20 | salalah
# Processing Record 3 of Set 20 | temaraia
# City not found. Skipping...
# Processing Record 4 of Set 20 | zalantun
# Processing Record 5 of Set 20 | ixtapa
# Processing Record 6 of Set 20 | nanortalik
# Processing Record 7 of Set 20 | sumbe
# Processing Record 8 of Set 20 | dzhusaly
# City not found. Skipping...
# Processing Record 9 of Set 20 | san juan
# Processing Record 10 of Set 20 | valley city
# Processing Record 11 of Set 20 | tarauaca
# Processing Record 12 of Set 20 | cidreira
# Processing Record 13 of Set 20 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 20 | port-gentil
# Processing Record 15 of Set 20 | hay river
# Processing Record 16 of Set 20 | vila franca do campo
# Processing Record 17 of Set 20 | pangnirtung
# Processing Record 18 of Set 20 | omboue
# Processing Record 19 of Set 20 | warrington
# Processing Record 20 of Set 20 | eureka
# Processing Record 21 of Set 20 | akureyri
# Processing Record 22 of Set 20 | souillac
# Processing Record 23 of Set 20 | montgomery
# Processing Record 24 of Set 20 | nemuro
# Processing Record 25 of Set 20 | katherine
# Processing Record 26 of Set 20 | meulaboh
# Processing Record 27 of Set 20 | santa maria
# Processing Record 28 of Set 20 | klaksvik
# Processing Record 29 of Set 20 | hithadhoo
# Processing Record 30 of Set 20 | vanavara
# Processing Record 31 of Set 20 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 20 | fort saint john
# City not found. Skipping...
# Processing Record 33 of Set 20 | tiruvottiyur
# City not found. Skipping...
# Processing Record 34 of Set 20 | ust-kut
# Processing Record 35 of Set 20 | shahr-e kord
# Processing Record 36 of Set 20 | kalmunai
# Processing Record 37 of Set 20 | krasnoselkup
# Processing Record 38 of Set 20 | veracruz
# Processing Record 39 of Set 20 | baghmara
# Processing Record 40 of Set 20 | severo-kurilsk
# Processing Record 41 of Set 20 | chegutu
# Processing Record 42 of Set 20 | xghajra
# City not found. Skipping...
# Processing Record 43 of Set 20 | namatanai
# Processing Record 44 of Set 20 | margate
# Processing Record 45 of Set 20 | brantford
# Processing Record 46 of Set 20 | charleston
# Processing Record 47 of Set 20 | berlevag
# Processing Record 48 of Set 20 | yeppoon
# Processing Record 49 of Set 20 | tampere
# Processing Record 50 of Set 20 | codrington
# Processing Record 1 of Set 21 | hailey
# Processing Record 2 of Set 21 | batticaloa
# Processing Record 3 of Set 21 | crewe
# Processing Record 4 of Set 21 | simbahan
# Processing Record 5 of Set 21 | bambous virieux
# Processing Record 6 of Set 21 | qusar
# Processing Record 7 of Set 21 | male
# Processing Record 8 of Set 21 | katsuura
# Processing Record 9 of Set 21 | tasiilaq
# Processing Record 10 of Set 21 | etchojoa
# Processing Record 11 of Set 21 | san patricio
# Processing Record 12 of Set 21 | gravdal
# Processing Record 13 of Set 21 | ilulissat
# Processing Record 14 of Set 21 | tecoanapa
# Processing Record 15 of Set 21 | ajdabiya
# Processing Record 16 of Set 21 | borovichi
# Processing Record 17 of Set 21 | puerto cabezas
# Processing Record 18 of Set 21 | bengkulu
# Processing Record 19 of Set 21 | carballo
# Processing Record 20 of Set 21 | padang
# Processing Record 21 of Set 21 | pevek
# Processing Record 22 of Set 21 | lebu
# Processing Record 23 of Set 21 | svetlogorsk
# Processing Record 24 of Set 21 | khatanga
# Processing Record 25 of Set 21 | hambantota
# Processing Record 26 of Set 21 | coihaique
# Processing Record 27 of Set 21 | pisco
# Processing Record 28 of Set 21 | springbok
# Processing Record 29 of Set 21 | roma
# Processing Record 30 of Set 21 | yalvac
# Processing Record 31 of Set 21 | qaqortoq
# Processing Record 32 of Set 21 | lancut
# Processing Record 33 of Set 21 | bozoum
# Processing Record 34 of Set 21 | mazatlan
# Processing Record 35 of Set 21 | escanaba
# Processing Record 36 of Set 21 | kurilsk
# Processing Record 37 of Set 21 | babaeski
# Processing Record 38 of Set 21 | fillan
# Processing Record 39 of Set 21 | hachinohe
# Processing Record 40 of Set 21 | cockburn town
# Processing Record 41 of Set 21 | surt
# Processing Record 42 of Set 21 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 21 | razgrad
# Processing Record 44 of Set 21 | mahebourg
# Processing Record 45 of Set 21 | esperance
# Processing Record 46 of Set 21 | broken hill
# Processing Record 47 of Set 21 | tupancireta
# Processing Record 48 of Set 21 | acarau
# Processing Record 49 of Set 21 | guanica
# Processing Record 50 of Set 21 | vostok
# Processing Record 1 of Set 22 | rawannawi
# City not found. Skipping...
# Processing Record 2 of Set 22 | jumla
# Processing Record 3 of Set 22 | hasaki
# Processing Record 4 of Set 22 | murray bridge
# Processing Record 5 of Set 22 | havoysund
# Processing Record 6 of Set 22 | komsomolskiy
# Processing Record 7 of Set 22 | westport
# Processing Record 8 of Set 22 | sabang
# Processing Record 9 of Set 22 | livingston
# Processing Record 10 of Set 22 | henzada
# City not found. Skipping...
# Processing Record 11 of Set 22 | redwater
# Processing Record 12 of Set 22 | scarborough
# Processing Record 13 of Set 22 | tuatapere
# Processing Record 14 of Set 22 | chapais
# Processing Record 15 of Set 22 | asyut
# Processing Record 16 of Set 22 | kabinda
# Processing Record 17 of Set 22 | resistencia
# Processing Record 18 of Set 22 | natal
# Processing Record 19 of Set 22 | victoria
# Processing Record 20 of Set 22 | atar
# Processing Record 21 of Set 22 | ambanja
# Processing Record 22 of Set 22 | goderich
# Processing Record 23 of Set 22 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 22 | bathsheba
# Processing Record 25 of Set 22 | conceicao do araguaia
# Processing Record 26 of Set 22 | homer
# Processing Record 27 of Set 22 | palmer
# Processing Record 28 of Set 22 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 22 | mayskiy
# Processing Record 30 of Set 22 | poum
# Processing Record 31 of Set 22 | mehamn
# Processing Record 32 of Set 22 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 22 | trinidad
# Processing Record 34 of Set 22 | ciudad guayana
# Processing Record 35 of Set 22 | faro
# Processing Record 36 of Set 22 | peterlee
# Processing Record 37 of Set 22 | ozinki
# Processing Record 38 of Set 22 | utiroa
# City not found. Skipping...
# Processing Record 39 of Set 22 | santa vitoria do palmar
# Processing Record 40 of Set 22 | bomet
# Processing Record 41 of Set 22 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 22 | hervey bay
# Processing Record 43 of Set 22 | estevan
# Processing Record 44 of Set 22 | satuba
# Processing Record 45 of Set 22 | evensk
# Processing Record 46 of Set 22 | fort nelson
# Processing Record 47 of Set 22 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 22 | hofn
# Processing Record 49 of Set 22 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 22 | matara
# Processing Record 1 of Set 23 | saint george
# Processing Record 2 of Set 23 | eyl
# Processing Record 3 of Set 23 | abbeville
# Processing Record 4 of Set 23 | ondjiva
# Processing Record 5 of Set 23 | hamilton
# Processing Record 6 of Set 23 | mareeba
# Processing Record 7 of Set 23 | sayyan
# Processing Record 8 of Set 23 | tuggurt
# City not found. Skipping...
# Processing Record 9 of Set 23 | kencong
# Processing Record 10 of Set 23 | imbituba
# Processing Record 11 of Set 23 | orange cove
# Processing Record 12 of Set 23 | den helder
# Processing Record 13 of Set 23 | pokhara
# Processing Record 14 of Set 23 | champerico
# Processing Record 15 of Set 23 | saldanha
# Processing Record 16 of Set 23 | lodeynoye pole
# Processing Record 17 of Set 23 | dingle
# Processing Record 18 of Set 23 | ballina
# Processing Record 19 of Set 23 | gimli
# Processing Record 20 of Set 23 | thompson
# Processing Record 21 of Set 23 | walvis bay
# Processing Record 22 of Set 23 | lake city
# Processing Record 23 of Set 23 | tandalti
# Processing Record 24 of Set 23 | konstantinovka
# Processing Record 25 of Set 23 | turan
# Processing Record 26 of Set 23 | sao bento do una
# City not found. Skipping...
# Processing Record 27 of Set 23 | kahului
# Processing Record 28 of Set 23 | gat
# Processing Record 29 of Set 23 | charters towers
# Processing Record 30 of Set 23 | prescott
# Processing Record 31 of Set 23 | krasnoarmeysk
# Processing Record 32 of Set 23 | bonavista
# Processing Record 33 of Set 23 | faridan
# City not found. Skipping...
# Processing Record 34 of Set 23 | altay
# Processing Record 35 of Set 23 | port macquarie
# Processing Record 36 of Set 23 | longyearbyen
# Processing Record 37 of Set 23 | christchurch
# Processing Record 38 of Set 23 | banda aceh
# Processing Record 39 of Set 23 | tanete
# Processing Record 40 of Set 23 | kupang
# Processing Record 41 of Set 23 | upernavik
# Processing Record 42 of Set 23 | birjand
# Processing Record 43 of Set 23 | avera
# Processing Record 44 of Set 23 | luceville
# City not found. Skipping...
# Processing Record 45 of Set 23 | north marysville
# City not found. Skipping...
# Processing Record 46 of Set 23 | jiddah
# City not found. Skipping...
# Processing Record 47 of Set 23 | anadyr
# Processing Record 48 of Set 23 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 23 | haines junction
# Processing Record 50 of Set 23 | murud
# Processing Record 1 of Set 24 | pacific grove
# Processing Record 2 of Set 24 | morro bay
# Processing Record 3 of Set 24 | werota
# Processing Record 4 of Set 24 | tommot
# Processing Record 5 of Set 24 | rochegda
# Processing Record 6 of Set 24 | morehead
# Processing Record 7 of Set 24 | kinsale
# Processing Record 8 of Set 24 | asfi
# Processing Record 9 of Set 24 | vitim
# Processing Record 10 of Set 24 | lavrentiya
# Processing Record 11 of Set 24 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 24 | alice springs
# Processing Record 13 of Set 24 | saurimo
# Processing Record 14 of Set 24 | agirish
# Processing Record 15 of Set 24 | mier
# Processing Record 16 of Set 24 | ponta delgada
# Processing Record 17 of Set 24 | chinhoyi
# Processing Record 18 of Set 24 | guangshui
# Processing Record 19 of Set 24 | mackay
# Processing Record 20 of Set 24 | kearney
# Processing Record 21 of Set 24 | atambua
# Processing Record 22 of Set 24 | yuanping
# Processing Record 23 of Set 24 | moen
# Processing Record 24 of Set 24 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 24 | nhulunbuy
# Processing Record 26 of Set 24 | labuhan
# Processing Record 27 of Set 24 | druzhba
# Processing Record 28 of Set 24 | ambon
# Processing Record 29 of Set 24 | sitka
# Processing Record 30 of Set 24 | beringovskiy
# Processing Record 31 of Set 24 | norman wells
# Processing Record 32 of Set 24 | nishihara
# Processing Record 33 of Set 24 | chabahar
# Processing Record 34 of Set 24 | tucuman
# Processing Record 35 of Set 24 | rayachoti
# Processing Record 36 of Set 24 | nova vicosa
# Processing Record 37 of Set 24 | svetlaya
# Processing Record 38 of Set 24 | morondava
# Processing Record 39 of Set 24 | fairbanks
# Processing Record 40 of Set 24 | iberia
# Processing Record 41 of Set 24 | parkent
# Processing Record 42 of Set 24 | usvyaty
# Processing Record 43 of Set 24 | sobolevo
# Processing Record 44 of Set 24 | henties bay
# Processing Record 45 of Set 24 | constitucion
# Processing Record 46 of Set 24 | nikolskoye
# Processing Record 47 of Set 24 | ahipara
# Processing Record 48 of Set 24 | cheremukhovo
# Processing Record 49 of Set 24 | okahandja
# Processing Record 50 of Set 24 | cairns
# Processing Record 1 of Set 25 | taoudenni
# Processing Record 2 of Set 25 | tefe
# Processing Record 3 of Set 25 | pamekasan
# Processing Record 4 of Set 25 | teya
# Processing Record 5 of Set 25 | aktau
# Processing Record 6 of Set 25 | akyab
# Processing Record 7 of Set 25 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 25 | isangel
# Processing Record 9 of Set 25 | candelaria
# Processing Record 10 of Set 25 | corrientes
# Processing Record 11 of Set 25 | vikulovo
# Processing Record 12 of Set 25 | farap
# Processing Record 13 of Set 25 | neuquen
# Processing Record 14 of Set 25 | divnogorsk
# Processing Record 15 of Set 25 | fukue
# Processing Record 16 of Set 25 | turayf
# Processing Record 17 of Set 25 | dourados
# Processing Record 18 of Set 25 | lasa
# Processing Record 19 of Set 25 | tari
# Processing Record 20 of Set 25 | tateyama
# Processing Record 21 of Set 25 | khuzdar
# Processing Record 22 of Set 25 | iguape
# Processing Record 23 of Set 25 | yulara
# Processing Record 24 of Set 25 | sokolo
# Processing Record 25 of Set 25 | ketchikan
# Processing Record 26 of Set 25 | pimentel
# Processing Record 27 of Set 25 | tomaszow mazowiecki
# Processing Record 28 of Set 25 | cheremshan
# Processing Record 29 of Set 25 | aksarka
# Processing Record 30 of Set 25 | angoram
# Processing Record 31 of Set 25 | tarakan
# Processing Record 32 of Set 25 | huai yot
# Processing Record 33 of Set 25 | bodden town
# Processing Record 34 of Set 25 | chittaurgarh
# Processing Record 35 of Set 25 | atoka
# Processing Record 36 of Set 25 | rio grande
# Processing Record 37 of Set 25 | san jose
# Processing Record 38 of Set 25 | watrous
# Processing Record 39 of Set 25 | lhokseumawe
# Processing Record 40 of Set 25 | dakar
# Processing Record 41 of Set 25 | saint-paul
# Processing Record 42 of Set 25 | marsh harbour
# Processing Record 43 of Set 25 | qasigiannguit
# Processing Record 44 of Set 25 | jonkoping
# Processing Record 45 of Set 25 | itarema
# Processing Record 46 of Set 25 | port arthur
# Processing Record 47 of Set 25 | pandan
# Processing Record 48 of Set 25 | tacuarembo
# Processing Record 49 of Set 25 | panjab
# Processing Record 50 of Set 25 | priiskovyy
# Processing Record 1 of Set 26 | ilo
# Processing Record 2 of Set 26 | vanimo
# Processing Record 3 of Set 26 | malwan
# City not found. Skipping...
# Processing Record 4 of Set 26 | port hardy
# Processing Record 5 of Set 26 | calbuco
# Processing Record 6 of Set 26 | ubinskoye
# Processing Record 7 of Set 26 | wajid
# Processing Record 8 of Set 26 | tranas
# Processing Record 9 of Set 26 | sataua
# City not found. Skipping...
# Processing Record 10 of Set 26 | urusha
# Processing Record 11 of Set 26 | sovetskiy
# Processing Record 12 of Set 26 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 26 | buxton
# Processing Record 14 of Set 26 | iracoubo
# Processing Record 15 of Set 26 | atbasar
# Processing Record 16 of Set 26 | san juan de uraba
# Processing Record 17 of Set 26 | saint-francois
# Processing Record 18 of Set 26 | pontes e lacerda
# Processing Record 19 of Set 26 | bonnyville
# Processing Record 20 of Set 26 | san quintin
# Processing Record 21 of Set 26 | alta floresta
# Processing Record 22 of Set 26 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 26 | cagliari
# Processing Record 24 of Set 26 | hovd
# Processing Record 25 of Set 26 | monrovia
# Processing Record 26 of Set 26 | adrar
# Processing Record 27 of Set 26 | bur gabo
# City not found. Skipping...
# Processing Record 28 of Set 26 | varadero
# Processing Record 29 of Set 26 | ibra
# Processing Record 30 of Set 26 | khonsa
# Processing Record 31 of Set 26 | shanghai
# Processing Record 32 of Set 26 | trojes
# Processing Record 33 of Set 26 | ingleside
# Processing Record 34 of Set 26 | pedernales
# Processing Record 35 of Set 26 | uvarovka
# Processing Record 36 of Set 26 | haverfordwest
# Processing Record 37 of Set 26 | bosaso
# Processing Record 38 of Set 26 | buin
# Processing Record 39 of Set 26 | pokaran
# Processing Record 40 of Set 26 | samfya
# Processing Record 41 of Set 26 | diplo
# Processing Record 42 of Set 26 | danilovka
# Processing Record 43 of Set 26 | lahat
# Processing Record 44 of Set 26 | koumac
# Processing Record 45 of Set 26 | riyadh
# Processing Record 46 of Set 26 | bwanga
# Processing Record 47 of Set 26 | andros
# Processing Record 48 of Set 26 | olga
# Processing Record 49 of Set 26 | boa vista
# Processing Record 50 of Set 26 | cieza
# Processing Record 1 of Set 27 | kanlagay
# Processing Record 2 of Set 27 | saint-joseph
# Processing Record 3 of Set 27 | ghanzi
# Processing Record 4 of Set 27 | la sarre
# Processing Record 5 of Set 27 | narsaq
# Processing Record 6 of Set 27 | kananga
# Processing Record 7 of Set 27 | vista hermosa
# Processing Record 8 of Set 27 | isla mujeres
# Processing Record 9 of Set 27 | toyooka
# Processing Record 10 of Set 27 | ushtobe
# Processing Record 11 of Set 27 | bubaque
# Processing Record 12 of Set 27 | touros
# Processing Record 13 of Set 27 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 27 | hirara
# Processing Record 15 of Set 27 | sinnamary
# Processing Record 16 of Set 27 | kichera
# Processing Record 17 of Set 27 | arlit
# Processing Record 18 of Set 27 | santa isabel
# Processing Record 19 of Set 27 | colac
# Processing Record 20 of Set 27 | batagay-alyta
# Processing Record 21 of Set 27 | comodoro rivadavia
# Processing Record 22 of Set 27 | manyana
# Processing Record 23 of Set 27 | bria
# Processing Record 24 of Set 27 | xiaoweizhai
# Processing Record 25 of Set 27 | gulariya
# Processing Record 26 of Set 27 | dawlatabad
# Processing Record 27 of Set 27 | umm bab
# Processing Record 28 of Set 27 | pattao
# Processing Record 29 of Set 27 | kamaishi
# Processing Record 30 of Set 27 | pringsewu
# Processing Record 31 of Set 27 | ndele
# Processing Record 32 of Set 27 | campoverde
# Processing Record 33 of Set 27 | sao borja
# Processing Record 34 of Set 27 | sao gabriel
# Processing Record 35 of Set 27 | niono
# Processing Record 36 of Set 27 | gazanjyk
# Processing Record 37 of Set 27 | iqaluit
# Processing Record 38 of Set 27 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 27 | lotofaga
# Processing Record 40 of Set 27 | carbondale
# Processing Record 41 of Set 27 | shemonaikha
# Processing Record 42 of Set 27 | tahta
# Processing Record 43 of Set 27 | acapulco
# Processing Record 44 of Set 27 | fortuna
# Processing Record 45 of Set 27 | acajutla
# Processing Record 46 of Set 27 | port-cartier
# Processing Record 47 of Set 27 | rocha
# Processing Record 48 of Set 27 | cabo san lucas
# Processing Record 49 of Set 27 | pandamatenga
# Processing Record 50 of Set 27 | isiolo
# Processing Record 1 of Set 28 | astana
# Processing Record 2 of Set 28 | markova
# Processing Record 3 of Set 28 | shenzhen
# Processing Record 4 of Set 28 | kosonsoy
# Processing Record 5 of Set 28 | saint-louis
# Processing Record 6 of Set 28 | mont-dore
# Processing Record 7 of Set 28 | tazovskiy
# Processing Record 8 of Set 28 | ambilobe
# Processing Record 9 of Set 28 | havelock
# Processing Record 10 of Set 28 | show low
# Processing Record 11 of Set 28 | angoche
# Processing Record 12 of Set 28 | campeche
# Processing Record 13 of Set 28 | sokoni
# Processing Record 14 of Set 28 | victor harbor
# Processing Record 15 of Set 28 | la ronge
# Processing Record 16 of Set 28 | luau
# Processing Record 17 of Set 28 | kericho
# Processing Record 18 of Set 28 | sinnai
# Processing Record 19 of Set 28 | kontagora
# Processing Record 20 of Set 28 | bandarbeyla
# Processing Record 21 of Set 28 | bereda
# Processing Record 22 of Set 28 | ifakara
# Processing Record 23 of Set 28 | rio gallegos
# Processing Record 24 of Set 28 | gaildorf
# Processing Record 25 of Set 28 | shirokiy
# Processing Record 26 of Set 28 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 28 | south lake tahoe
# Processing Record 28 of Set 28 | lawrence
# Processing Record 29 of Set 28 | shellbrook
# Processing Record 30 of Set 28 | killybegs
# Processing Record 31 of Set 28 | nouadhibou
# Processing Record 32 of Set 28 | teguldet
# Processing Record 33 of Set 28 | mwense
# Processing Record 34 of Set 28 | vangaindrano
# Processing Record 35 of Set 28 | mecca
# Processing Record 36 of Set 28 | baoqing
# Processing Record 37 of Set 28 | coquimbo
# Processing Record 38 of Set 28 | sorong
# Processing Record 39 of Set 28 | shache
# Processing Record 40 of Set 28 | encruzilhada do sul
# Processing Record 41 of Set 28 | pandan niog
# Processing Record 42 of Set 28 | porosozero
# Processing Record 43 of Set 28 | vinces
# Processing Record 44 of Set 28 | koungou
# Processing Record 45 of Set 28 | ambodifototra
# City not found. Skipping...
# Processing Record 46 of Set 28 | sisimiut
# Processing Record 47 of Set 28 | kondinskoye
# Processing Record 48 of Set 28 | dudinka
# Processing Record 49 of Set 28 | mayumba
# Processing Record 50 of Set 28 | valparaiso
# Processing Record 1 of Set 29 | amahai
# Processing Record 2 of Set 29 | willowmore
# Processing Record 3 of Set 29 | arica
# Processing Record 4 of Set 29 | diego de almagro
# Processing Record 5 of Set 29 | tessalit
# Processing Record 6 of Set 29 | tokur
# Processing Record 7 of Set 29 | hobyo
# Processing Record 8 of Set 29 | yala
# Processing Record 9 of Set 29 | flin flon
# Processing Record 10 of Set 29 | sechura
# Processing Record 11 of Set 29 | san cristobal
# Processing Record 12 of Set 29 | xuddur
# Processing Record 13 of Set 29 | kysyl-syr
# Processing Record 14 of Set 29 | westpunt
# City not found. Skipping...
# Processing Record 15 of Set 29 | piney green
# Processing Record 16 of Set 29 | ulaanbaatar
# Processing Record 17 of Set 29 | bambanglipuro
# Processing Record 18 of Set 29 | kauhajoki
# Processing Record 19 of Set 29 | esmeraldas
# Processing Record 20 of Set 29 | grand gaube
# Processing Record 21 of Set 29 | kodinsk
# Processing Record 22 of Set 29 | lorengau
# Processing Record 23 of Set 29 | dobryatino
# Processing Record 24 of Set 29 | sembabule
# Processing Record 25 of Set 29 | cartagena
# Processing Record 26 of Set 29 | tabory
# Processing Record 27 of Set 29 | trelew
# Processing Record 28 of Set 29 | neulengbach
# Processing Record 29 of Set 29 | xam nua
# Processing Record 30 of Set 29 | lompoc
# Processing Record 31 of Set 29 | whitehorse
# Processing Record 32 of Set 29 | east wenatchee bench
# Processing Record 33 of Set 29 | rach gia
# Processing Record 34 of Set 29 | itaituba
# Processing Record 35 of Set 29 | katha
# City not found. Skipping...
# Processing Record 36 of Set 29 | ulladulla
# Processing Record 37 of Set 29 | pinheiro machado
# Processing Record 38 of Set 29 | chongqing
# Processing Record 39 of Set 29 | oxelosund
# Processing Record 40 of Set 29 | saint-augustin
# Processing Record 41 of Set 29 | ola
# Processing Record 42 of Set 29 | formosa do rio preto
# Processing Record 43 of Set 29 | pimenteiras
# Processing Record 44 of Set 29 | aksarayskiy
# Processing Record 45 of Set 29 | taltal
# Processing Record 46 of Set 29 | dwarka
# Processing Record 47 of Set 29 | matay
# Processing Record 48 of Set 29 | coahuayana
# Processing Record 49 of Set 29 | ruangwa
# Processing Record 50 of Set 29 | uruzgan
# Processing Record 1 of Set 30 | talakan
# Processing Record 2 of Set 30 | saint anthony
# Processing Record 3 of Set 30 | dandong
# Processing Record 4 of Set 30 | miri
# Processing Record 5 of Set 30 | kirzhach
# Processing Record 6 of Set 30 | najran
# Processing Record 7 of Set 30 | beloha
# Processing Record 8 of Set 30 | celendin
# Processing Record 9 of Set 30 | skjervoy
# Processing Record 10 of Set 30 | kawalu
# Processing Record 11 of Set 30 | jalu
# Processing Record 12 of Set 30 | bulaevo
# Processing Record 13 of Set 30 | shu
# Processing Record 14 of Set 30 | ostrovnoy
# Processing Record 15 of Set 30 | stromness
# Processing Record 16 of Set 30 | mikuni
# Processing Record 17 of Set 30 | flinders
# Processing Record 18 of Set 30 | klaeng
# Processing Record 19 of Set 30 | maksatikha
# Processing Record 20 of Set 30 | hudson bay
# Processing Record 21 of Set 30 | bouar
# Processing Record 22 of Set 30 | zhicheng
# Processing Record 23 of Set 30 | robertsport
# Processing Record 24 of Set 30 | madison
# Processing Record 25 of Set 30 | agadez
# Processing Record 26 of Set 30 | constantine
# Processing Record 27 of Set 30 | thunder bay
# Processing Record 28 of Set 30 | sao joao da barra
# Processing Record 29 of Set 30 | nurota
# Processing Record 30 of Set 30 | kasongo-lunda
# Processing Record 31 of Set 30 | rivera
# Processing Record 32 of Set 30 | nakusp
# Processing Record 33 of Set 30 | puerto carreno
# Processing Record 34 of Set 30 | baglan
# Processing Record 35 of Set 30 | camopi
# Processing Record 36 of Set 30 | yaring
# Processing Record 37 of Set 30 | sungaipenuh
# Processing Record 38 of Set 30 | yeletskiy
# City not found. Skipping...
# Processing Record 39 of Set 30 | puerto ayacucho
# Processing Record 40 of Set 30 | tanout
# Processing Record 41 of Set 30 | manaure
# Processing Record 42 of Set 30 | massaguet
# Processing Record 43 of Set 30 | cowra
# Processing Record 44 of Set 30 | balykshi
# Processing Record 45 of Set 30 | eskasem
# City not found. Skipping...
# Processing Record 46 of Set 30 | watsa
# Processing Record 47 of Set 30 | gurgan
# City not found. Skipping...
# Processing Record 48 of Set 30 | mitchell
# Processing Record 49 of Set 30 | laguna
# Processing Record 50 of Set 30 | lazaro cardenas
# Processing Record 1 of Set 31 | necochea
# Processing Record 2 of Set 31 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 31 | san isidro
# Processing Record 4 of Set 31 | baie-comeau
# Processing Record 5 of Set 31 | nome
# Processing Record 6 of Set 31 | waw
# Processing Record 7 of Set 31 | junction city
# Processing Record 8 of Set 31 | soe
# Processing Record 9 of Set 31 | kropotkin
# Processing Record 10 of Set 31 | makakilo city
# Processing Record 11 of Set 31 | kismayo
# Processing Record 12 of Set 31 | vila do maio
# Processing Record 13 of Set 31 | isoka
# Processing Record 14 of Set 31 | terney
# Processing Record 15 of Set 31 | san rafael
# Processing Record 16 of Set 31 | colombia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Chokurdakh      RU  70.6333  147.9167    -14.13        89         100
# 1       Carnarvon      AU -24.8667  113.6333     77.00       100           0
# 2   Prince George      CA  53.9166 -122.7530     44.01        48          75
# 3      Georgetown      MY   5.4112  100.3354     79.00        94          20
# 4            Hilo      US  19.7297 -155.0900     71.60        78          90
# 5     Antofagasta      CL -23.6500  -70.4000     73.00        73          20
# 6        Straumen      NO  63.8709   11.2999     30.99        93          40
# 7          Faanui      PF -16.4833 -151.7500     81.61        77         100
# 8        Hermanus      ZA -34.4187   19.2345     61.00        90          98
# 9  Port Elizabeth      ZA -33.9180   25.5701     68.00        88          90
#
#    Wind Speed   Weather Description
# 0       11.95       overcast clouds
# 1        9.22             clear sky
# 2       14.97         broken clouds
# 3        4.61            few clouds
# 4        5.93  heavy intensity rain
# 5       17.27            few clouds
# 6        5.75      scattered clouds
# 7       18.68            light rain
# 8        6.98       overcast clouds
# 9        9.22            light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
